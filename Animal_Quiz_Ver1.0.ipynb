# %%
# INFINITE LOOPS
# Escaping infinity
# pg no 34

while True:
    answer = input ('Are you bored yet? (y/n)')
    if answer == 'y':
        print ('How rude!')
        break
# Out:
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) n
# Are you bored yet? (y/n) y
# How rude!

# %%
# LOOPS INSIDE LOOPS
# One loop inside another
# pg no 35

for hooray_counter in range (1, 4):
    for hip_counter in range (1, 3):
        print ('Hip')
    print ('Hooray! \n')
# Out:
# Hip
# Hip
# Hooray!
#
# Hip
# Hip
# Hooray!
#
# Hip
# Hip
# Hooray!

# %%
# ANIMAL QUIZ
# Putting it together
# pg no 38

# Building a 'CHECK FUNCTION'
# ===========================

def check_guess (guess, answer):
    global score
    still_guessing = True
    attempt = 0
    while still_guessing and attempt < 3:
        if guess.lower() == answer.lower():
            print ('Correct answer \n')
            score = score + 1
            still_guessing = False
        else:
            if attempt < 2:
                guess = input ('Sorry wrong answer. Try again.')
                attempt = attempt + 1
                if attempt == 3:
                    print ('The correct answer is ' + answer)

# Main 'ANIMAL QIUZ' program
# ==========================

score = 0
print ('GUESS THE ANIMAL!')
guess1 = input ('Which bear lives at the North Pole? ')
check_guess (guess1, 'polar bear')

guess2 = input ('Which is the fastest land animal? ')
check_guess (guess2, 'cheetah')

guess3 = input ('Which is the laregst animal?')
check_guess (guess3, 'blue whale')

# Display of Score
# ================

print ('Your score is ' + str(score))
# Out:
# GUESS THE ANIMAL!
# Which bear lives at the North Pole?  polar bk
# Sorry wrong answer. Try again. posdf
# Sorry wrong answer. Try again. polar bear
# Correct answer
# Which is the fastest land animal?  cheetag
# Sorry wrong answer. Try again. cheetah
# Correct answer
# Which is the laregst animal? blue whale
# Correct answer
#
# Your score is 3
