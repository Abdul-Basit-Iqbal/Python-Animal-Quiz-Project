# %%
# ANIMAL QUIZ
# Putting it together
# pg no 38

# Building a 'CHECK FUNCTION'
# ===========================

def check_guess (guess, answer):
    global score
#    still_guessing = True
    attempt = 0

    while attempt < 3:
        if guess.lower() == answer.lower():
            print ('Correct answer \n')
            score = score + 1
            return      # exit function immediately
        else:
            attempt += 1
            if attempt < 3:
                guess = input ('Sorry wrong answer. Try again: ')
# This runs after 3rd failed attempt
            print ('The correct anwer is ' + answer)

#        else:
 #           if attempt < 2:
  #              guess = input ('Sorry wrong answer. Try again.')
   #             attempt = attempt + 1
    #            if attempt == 3:
     #               print ('The correct answer is ' + answer)

# Main 'ANIMAL QIUZ' program
# ==========================

score = 0
print ('GUESS THE ANIMAL!')
guess1 = input ('Which bear lives at the North Pole? ')
check_guess (guess1, 'polar bear')

guess2 = input ('Which is the fastest land animal? ')
check_guess (guess2, 'cheetah')

guess3 = input ('Which is the largest animal? ')
check_guess (guess3, 'blue whale')

guess4 = input ('Which animal has a long trunk? ')
check_guess (guess4, 'elephant')

guess5 = input ('Which kind of mammal can fly? ')
check_guess (guess5, 'bat')

guess6 = input ('How many heart does an octopus have? ')
check_guess (guess6, 'three')

guess7 = input ('which one of these is a fish? \n A) Whale B) Dolphin C) Shark D) Squid.\n Type A, B, C, or D')
check_guess (guess7, 'C')

# Display of Score
# ================

print ('Your score is ' + str(score))
# Out:
# GUESS THE ANIMAL!
